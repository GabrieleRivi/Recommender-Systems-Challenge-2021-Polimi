# %%
import os

os.chdir('/Users/gabriele/PycharmProjects/RecSys')

from src.HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
from src.Recommenders.KNN.ItemKNN_CFCBF_Hybrid_Recommender import ItemKNN_CFCBF_Hybrid_Recommender
from Utils.utils import create_URM,create_ICM,combine_matrices
from src.Evaluation.Evaluator import EvaluatorHoldout
from src.Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from skopt.space import Real, Categorical, Integer

# %%
URM = create_URM()
ICM = create_ICM()

URM_train_validation,URM_test = split_train_in_two_percentage_global_sample(URM,train_percentage=0.85)
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_train_validation,train_percentage=0.85)

combined_matrices = combine_matrices(ICM=ICM, URM=URM_train)

evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[10])
evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
# Out:
# ...
# EvaluatorHoldout: Ignoring 13635 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 13636 ( 0.1%) Users that have less than 1 test interactions

# %%
from src.HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

hyperparameters_range_dictionary = {
    "topK": Integer(100,200),
    "shrink": Real(1,100),
    "similarity": Categorical(["cosine"])
}

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [combined_matrices,ICM],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train_validation],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

tuning_class = SearchBayesianSkopt(recommender_class=ItemKNN_CFCBF_Hybrid_Recommender,
                                   evaluator_validation=evaluator_validation,
                                   evaluator_test=evaluator_test)

n_cases = 50
n_random_starts = n_cases*0.3
output_folder_path = "logs/"

tuning_class.search(recommender_input_args=recommender_input_args,
                    recommender_input_args_last_test=recommender_input_args_last_test, 
                    hyperparameter_search_space=hyperparameters_range_dictionary,
                    metric_to_optimize="MAP",
                    cutoff_to_optimize= 10,
                    n_cases= n_cases,
                    n_random_starts=n_random_starts,
                    output_folder_path=output_folder_path,
                    output_file_name_root=ItemKNN_CFCBF_Hybrid_Recommender.RECOMMENDER_NAME,
                    save_model="best"
                    )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 115, 'shrink': 71.45778612325311, 'similarity': 'cosine'}
# ItemKNN_CFCBF_HybridRecommender: ICM Detected 1 ( 0.0%) items with no features.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 18059 (100.0%), 1177.36 column/sec. Elapsed time 15.34 sec
# EvaluatorHoldout: Processed 13636 (100.0%) in 10.66 sec. Users per second: 1279
# ...

# %%
##Best config is 51: {'topK': 174, 'ICM_weight': 0.1, 'shrink': 10.0, 'similarity': 'cosine'}
##Best config is 41: {'topK': 174, 'shrink': 54.93865189896452, 'similarity': 'cosine'}
rec1=ItemKNN_CFCBF_Hybrid_Recommender(ICM_train=ICM,URM_train=URM_train)
rec1.fit(topK=174, ICM_weight=0.1, shrink=10, similarity='cosine')
# Out:
# ItemKNN_CFCBF_HybridRecommender: ICM Detected 1 ( 0.0%) items with no features.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 18059 (100.0%), 1195.04 column/sec. Elapsed time 15.11 sec

# %%
rec2=ItemKNN_CFCBF_Hybrid_Recommender(ICM_train=ICM,URM_train=URM_train)
rec2.fit(topK=174, shrink=54.93865189896452, similarity='cosine')
# Out:
# ItemKNN_CFCBF_HybridRecommender: ICM Detected 1 ( 0.0%) items with no features.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 18059 (100.0%), 1204.38 column/sec. Elapsed time 14.99 sec

# %%
result_df, _ =evaluator_test.evaluateRecommender(rec1)
print(result_df.loc[10])
# Out:
# EvaluatorHoldout: Processed 13635 (100.0%) in 12.28 sec. Users per second: 1110
# PRECISION                     0.231096
# PRECISION_RECALL_MIN_DEN      0.233348
# RECALL                        0.053419
# MAP                           0.114924
# MAP_MIN_DEN                   0.115845
# MRR                           0.460814
# NDCG                           0.24076
# F1                            0.086778
# HIT_RATE                      0.893289
# ARHR_ALL_HITS                 0.723652
# NOVELTY                       0.005309
# AVERAGE_POPULARITY            0.668005
# DIVERSITY_MEAN_INTER_LIST     0.805193
# DIVERSITY_HERFINDAHL          0.980513
# COVERAGE_ITEM                 0.057201
# COVERAGE_ITEM_CORRECT         0.026469
# COVERAGE_USER                 0.998901
# COVERAGE_USER_CORRECT         0.892308
# DIVERSITY_GINI                0.004055
# SHANNON_ENTROPY               6.388723
# RATIO_DIVERSITY_HERFINDAHL    0.980892
# RATIO_DIVERSITY_GINI          0.016347
# ...

# %%
result_df, _ =evaluator_test.evaluateRecommender(rec2)
print(result_df.loc[10])
# Out:
# EvaluatorHoldout: Processed 13635 (100.0%) in 12.45 sec. Users per second: 1095
# PRECISION                     0.230334
# PRECISION_RECALL_MIN_DEN      0.232569
# RECALL                        0.053293
# MAP                           0.114671
# MAP_MIN_DEN                   0.115587
# MRR                           0.461141
# NDCG                          0.240287
# F1                            0.086558
# HIT_RATE                      0.893069
# ARHR_ALL_HITS                  0.72307
# NOVELTY                       0.005295
# AVERAGE_POPULARITY            0.673173
# DIVERSITY_MEAN_INTER_LIST     0.799872
# DIVERSITY_HERFINDAHL          0.979981
# COVERAGE_ITEM                 0.052993
# COVERAGE_ITEM_CORRECT         0.024309
# COVERAGE_USER                 0.998901
# COVERAGE_USER_CORRECT         0.892088
# DIVERSITY_GINI                0.003793
# SHANNON_ENTROPY               6.319932
# RATIO_DIVERSITY_HERFINDAHL    0.980359
# RATIO_DIVERSITY_GINI          0.015291
# ...
